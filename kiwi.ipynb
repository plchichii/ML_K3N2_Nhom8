# %% [markdown]
# <a href="https://colab.research.google.com/github/plchichii/ML_K3N2_Nhom8/blob/nhap/kiwi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("sói hoang kiwi")
print("sói hoang cà chua")
